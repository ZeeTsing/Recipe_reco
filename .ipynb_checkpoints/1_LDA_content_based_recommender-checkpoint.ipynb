# %%
import pandas as pd
import numpy as np
import gensim
import random
from sklearn.feature_extraction.text import CountVectorizer
from gensim.matutils import Sparse2Corpus
from gensim.models.ldamodel import LdaModel
from gensim import models, similarities
from gensim.corpora import Dictionary

seed = 0

# %%
data = pd.read_pickle('data/raw_df.pkl')

# %%
def treat_ingredients(ing_list):
    output = []
    for ingredient in ing_list:
        ingredient_list = ingredient.split(' ')
        output.append("_".join(ingredient_list))
    return output

# %%
def get_similarity(lda, query_vector):
    index = similarities.MatrixSimilarity(lda[corpus])
    sims = index[query_vector]
    return sims

# %%
def train_lda_model(ingredients,num_topics = 100,passes = 15,random_state = seed):
    # get list of ingredients transformed
    ingredients_all = ingredients.apply(lambda x: treat_ingredients(x))
    
    #build dict (for Gensim vectorizer)
    dictionary = Dictionary([ing for ing in list(ingredients_all)])
    
    # build corpus
    corpus = [dictionary.doc2bow(text) for text in list(ingredients_all)]
    
    #train lda
    ldamodel = LdaModel(corpus,num_topics = num_topics, passes = passes,random_state = random_state, id2word = dictionary)
    return ldamodel,dictionary,corpus

# %%
sample_w = "butter, salt, pepper"

# %%
# define treat input function, returning a list of tokenized ingredients
def treat_words (words):
    list_words = words.split(",")
    output = []
    for w in list_words:
        output.append("_".join(w.strip().split(" ")))
    return output

# %%
def calculate_similarity(query,ldamodel,dct):
    # treat input words
    words_bow = dct.doc2bow(treat_words(query))
    query_vector = ldamodel[words_bow]
    
    #calculate ranking
    sim_rank = get_similarity(lda = ldamodel, query_vector = query_vector)
    sim_rank = sorted(enumerate(sim_rank), key=lambda item: -item[1])
    
    return sim_rank

# %%
def calculate_recommendation(sim_rank,groups,n_reco = 10):
    results = [sim_rank[0][0]]
    results_prob = [sim_rank[0][1]]
    result_group = [sim_rank[0][1]]
        
    for recipe,group in zip(sim_rank[1:],groups[1:]):
        if group not in set(result_group):
            results.append(recipe[0])
            result_group.append(group)
            results_prob.append(recipe[1])
        if len(results) == n_reco:
            break
    print(result_group,"\n",results_prob)
    return results

# %%
# this is a wrapper function for calculate simu and calculate reco
def get_similarity_reco (query,ldamodel,dct,corpus,n_reco = 10):
    #calculate rank
    sim_rank = calculate_similarity(query,ldamodel,dct)
    #find groups according to lda model
    groups = []
    for l in ldamodel[corpus]:
        try:
            groups.append(l[0][0])
        except:
            groups.append(random.randint(1, 100))
            
    return calculate_recommendation(sim_rank,groups,n_reco)

# %%
def print_reco(results):
    return data.iloc[results]

# %%
def pretty_name (name):
    return " ".join([ word.capitalize() for word in name.split(" ") if word != ""])

# %%
ldamodel,dictionary,corpus = train_lda_model(data.ingredients)

# %%
query = "flour, chocolate"

# %%
results = get_similarity_reco (query, ldamodel, dct = dictionary, corpus = corpus,n_reco = 10)
# Out:
# [1.0, 60, 10, 55, 2, 41, 14, 43, 19, 42]
#  [1.0, 0.95025396, 0.95025265, 0.8892121, 0.8861892, 0.8858435, 0.88212824, 0.88162076, 0.8612087, 0.8576546]

# %%
print_reco(results)
# Out:
#                                    name      id  minutes  contributor_id  \
# 27419                       bowl of sin   48499      105           34122
# 82376    fast and easy black forest pie   80300       15          103876
# 155904  peanut butter chocolate pudding   79686       15           89831
# 23701       biscota thipla me marmelada  135019       25          209255
# 85466              fondants au chocolat  179842       27          141569
# 142979     nearly no fat fudge brownies  429805       30          798353
# 53102     churros from spain  authentic  398614       40         1430306
# 27173                       bounty cake  217580       60          444015
# 51817           chocolate toffee trifle  224474        6          251917
# 95523          grandmother s sugar cake  179512       55          293946
#
#          submitted                                               tags  \
# 27419   2002-12-12  [weeknight, time-to-make, course, main-ingredi...
# 82376   2004-01-06  [15-minutes-or-less, time-to-make, course, mai...
# 155904  2003-12-29  [15-minutes-or-less, time-to-make, course, mai...
# 23701   2005-08-26  [30-minutes-or-less, time-to-make, course, cui...
# 85466   2006-07-31  [30-minutes-or-less, time-to-make, course, mai...
# 142979  2010-06-15  [30-minutes-or-less, time-to-make, course, pre...
# 53102   2009-11-09  [weeknight, 60-minutes-or-less, time-to-make, ...
# 27173   2007-03-20  [60-minutes-or-less, time-to-make, course, mai...
# 51817   2007-04-24  [15-minutes-or-less, time-to-make, course, mai...
# 95523   2006-07-27  [60-minutes-or-less, time-to-make, course, pre...
#
#                                               nutrition  n_steps  \
# 27419      [665.2, 46.0, 260.0, 33.0, 11.0, 75.0, 29.0]        9
# 82376   [1814.4, 126.0, 481.0, 99.0, 43.0, 203.0, 83.0]        8
# 155904        [178.6, 12.0, 42.0, 14.0, 9.0, 18.0, 7.0]        8
# 23701        [320.3, 20.0, 68.0, 7.0, 14.0, 30.0, 14.0]       14
# 85466        [400.4, 55.0, 61.0, 8.0, 14.0, 108.0, 7.0]       12
# 142979          [107.9, 5.0, 40.0, 1.0, 6.0, 10.0, 6.0]        5
# 53102       [1055.9, 53.0, 5.0, 54.0, 62.0, 99.0, 56.0]       11
# 27173      [538.0, 68.0, 109.0, 7.0, 16.0, 153.0, 11.0]       10
# 51817     [674.1, 54.0, 159.0, 35.0, 20.0, 105.0, 27.0]        7
# 95523      [472.0, 39.0, 137.0, 15.0, 12.0, 25.0, 18.0]       12
#
#                                                     steps  \
# 27419   [prepare cake according to directions in a 9x1...
# 82376   [spread 1 cup of whipped topping on bottom of ...
# 155904  [in a small bowl , mix 2 tbsp milk with the pe...
# 23701   [sift flour with baking powder into a bowl, ma...
# 85466   [melt the chocolate, add 80 g of butter to the...
# 142979  [preheat oven to 350 degrees f, mix chocolate ...
# 53102   [we heat water with salt in a large saucepan, ...
# 27173   [for the sponge-cake:, separate egg whites and...
# 51817   [cut up frozen pound cake into bite sized piec...
# 95523   [grease 6 cup fluted tube pan, sprinkle entire...
#
#                                               description  \
# 27419   i got this recipe from the newspaper in richmo...
# 82376   this is a great pie to make during the week wh...
# 155904  a wonderful and easy to prepare ending to any ...
# 23701   yield is a guess, it depends on what size of c...
# 85466   as i am a chocolate-lover, this has to be one ...
# 142979  this came from the top of the 'astro" yogurt c...
# 53102    delicious fried churros, a tradition from spain.
# 27173         my favourite cake. just like the candy bar.
# 51817   this is my cousin teri's recipe. very easy to ...
# 95523   this is from my mom's recipe cards.  i have no...
#
#                                               ingredients  n_ingredients
# 27419   [chocolate cake mix, coffee liqueur, instant c...              5
# 82376   [chocolate graham wafer pie crust, whipped top...              5
# 155904  [milk, chunky peanut butter, whipped topping, ...              4
# 23701   [flour, baking powder, eggs, sugar, vanilla, b...             12
# 85466              [chocolate, butter, sugar, eggs, salt]              5
# 142979  [chocolate, plain fat-free yogurt, sugar, flou...              7
# 53102   [flour, baking powder, water, salt, eggs, choc...              6
# 27173           [eggs, sugar, coconut, chocolate, butter]              5
# 51817   [butter pound cake, instant chocolate pudding ...              5
# 95523   [breadcrumbs, flour, baking powder, eggs, suga...              9
